# %%
## Import

# %matplotlib inline
import numpy as np
import pandas as pd
import os
import urllib.request
import datetime
import gzip
import shutil

# %% [markdown]
# ## Read in the data

# %%
listing_col = ['id',
               'listing_url',
               'name',
               'price',
               'summary',
               'host_id',
               'host_name',
               'host_about',
               'host_since',
               'host_listings_count',
               'host_total_listings_count',
               'host_response_rate',
               'description',
               'neighbourhood_cleansed',
               'property_type',
               'room_type',
               'price',
               'number_of_reviews',
               'instant_bookable',
               'review_scores_rating',
               'beds',
               'bedrooms',
               'bathrooms',
               'accommodates',
               'minimum_nights',
               'maximum_nights',
               'amenities', # Betekent voorzieningen
               'cancellation_policy',
               'reviews_per_month',
               'first_review',
               'last_review',
               'reviews_per_month',
               'review_scores_rating',
               'latitude',
               'longitude',
               'availability_30',
               'availability_60',
               'availability_90',
               'availability_365'              
              ]

url = 'http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2018-01-10/data/listings.csv.gz'
filename = 'listings_2018-01-10.csv.gz'
urllib.request.urlretrieve(url, filename)
unfilled = gzip.open(filename)
df_listings = pd.read_csv(unfilled, usecols=listing_col)
df_listings['publicatie'] = '2018-01-10'
        

our_dates= []
start = datetime.datetime.strptime("11-01-2018", "%d-%m-%Y")  # we can change this
end = datetime.datetime.strptime("31-12-2018", "%d-%m-%Y")    # we can change this
date_generated = [start + datetime.timedelta(days=x) for x in range(0, (end-start).days)]

for date in date_generated:
    our_dates.append(date.strftime("%Y-%m-%d"))

    
item = "listings" ## We can also extract reviews and calanders
    
for date in our_dates:
    url = "http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/" +date+ "/data/"+item+".csv.gz"
    filename = item +"_"+ date +".csv.gz" 
    file_python = item +"_"+ date
    try:
        urllib.request.urlretrieve(url, filename)
        print("found : " + date)
        unfilled = gzip.open(filename)
#         df_reviews[file_python] = pd.read_csv(unfilled)
        temp = pd.read_csv(unfilled, usecols=listing_col)
        temp['publicatie'] = date
        
        df_listings.append(temp)
        
        
    except urllib.error.URLError as e:
        print(e.reason)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-f1d4cc4489eb> in <module>()
#      42 url = 'http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2018-01-10/data/listings.csv.gz'
#      43 filename = 'listings_2018-01-10.csv.gz'
# ---> 44 urllib.request.urlretrieve(url, filename)
#      45 unfilled = gzip.open(filename)
#      46 df_listings = pd.read_csv(unfilled, usecols=listing_col)
#
# ~\Anaconda3\lib\urllib\request.py in urlretrieve(url, filename, reporthook, data)
#     275
#     276             while True:
# --> 277                 block = fp.read(bs)
#     278                 if not block:
#     279                     break
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     491         # connection, and the user is reading more bytes than will be provided
#     492         # (for example, reading in 1k chunks)
# --> 493         n = self.fp.readinto(b)
#     494         if not n and b:
#     495             # Ideally, we would raise IncompleteRead if the content-length
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
url = 'http://data.insideairbnb.com/the-netherlands/north-holland/amsterdam/2019-01-13/data/listings.csv.gz'
filename = 'listings_2019-01-13.csv.gz'
urllib.request.urlretrieve(url, filename)
unfilled = gzip.open(filename)
df_listings = pd.read_csv(unfilled, usecols=listing_col)
# df_listings['publicatie'] = '2019-01-13'

del unfilled

# %% [markdown]
# ## Making the dataframe

# %%
df_listings['price'] = pd.to_numeric(df_listings['price'].str.replace(',','').str.replace('$',''))

# Group by columns
price = df_listings.groupby(df_listings.neighbourhood_cleansed).price.mean()
listings =df_listings.groupby(df_listings.neighbourhood_cleansed).id.nunique()
accounts = df_listings.groupby(df_listings.neighbourhood_cleansed).host_id.nunique()

area_overview = pd.concat((price,listings,accounts), axis=1, join='inner').reset_index()
area_overview.rename(columns={'neighbourhood_cleansed': 'name', 'price': 'avg_price_night', 'id':'listings', 'host_id':'accounts'}, inplace=True)

## Tijdelijk dummy values voor volgende kolommen
# area_overview["listings_per_ha"]  = area_overview["listings"] /3
# area_overview["percentage_high_availability"] = area_overview["listings"] / 4
# area_overview["percentage_host_with_multiple_listings"] = area_overview["listings"] /5
# area_overview["duplicates"] = area_overview["listings"] / 6
# area_overview["risk_rank"] = area_overview["listings"] / 7

## reorder the names
area_overview = area_overview.reindex(columns=['name','accounts','listings','avg_price_night'])

## Show result
area_overview


# accounts unfold_more	# listings unfold_more	price/night unfold_more	% high availability unfold_more	% multiple listings unfold_more	# duplicates unfold_more

# risico_rank
# Out:
#                                       name  accounts  listings  \
# 0                          Bijlmer-Centrum        94       109
# 1                             Bijlmer-Oost        82       102
# 2                            Bos en Lommer      1036      1137
# 3                   Buitenveldert - Zuidas       224       237
# 4                             Centrum-Oost      1439      1775
# 5                             Centrum-West      1850      2317
# 6                   De Aker - Nieuw Sloten       112       130
# 7                   De Baarsjes - Oud-West      3173      3480
# 8                  De Pijp - Rivierenbuurt      2242      2494
# 9                    Gaasperdam - Driemond       102       119
# 10                 Geuzenveld - Slotermeer       180       206
# 11                IJburg - Zeeburgereiland       403       443
# 12                              Noord-Oost       226       254
# 13                              Noord-West       286       323
# 14  Oostelijk Havengebied - Indische Buurt       878       958
# 15                                  Osdorp       134       157
# 16                               Oud-Noord       508       572
# 17                                Oud-Oost      1146      1254
# 18                             Slotervaart       349       391
# 19                         Watergraafsmeer       513       547
# 20                              Westerpark      1331      1468
# 21                                    Zuid      1291      1437
#
#     avg_price_night
# 0         91.073394
# 1         99.813725
# 2        117.425682
# 3        150.940928
# 4        188.936901
# 5        189.206733
# 6        126.423077
# 7        143.556609
# 8        157.072173
# 9         95.336134
# 10       126.135922
# 11       167.417607
# 12       118.039370
# 13       118.823529
# 14       125.981211
# 15        97.375796
# 16       158.945804
# 17       143.793461
# 18       112.109974
# 19       139.497258
# 20       140.767711
# 21       171.004871

# %%
inside_airbnb = pd.read_excel("data_inside_airbnb.xlsx", error_bad_lines=False)

# %%
area_overview = area_overview.merge(inside_airbnb, left_on='name', right_on='neighbourhood', how='left')

# %%
df_listings.head()
# Out:
#       id                         listing_url  \
# 0   2818   https://www.airbnb.com/rooms/2818
# 1  20168  https://www.airbnb.com/rooms/20168
# 2  25428  https://www.airbnb.com/rooms/25428
# 3  27886  https://www.airbnb.com/rooms/27886
# 4  28658  https://www.airbnb.com/rooms/28658
#
#                                                 name  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1         100%Centre-Studio 1 Private Floor/Bathroom
# 2                Lovely apt in City Centre (Jordaan)
# 3  Romantic, stylish B&B houseboat in canal district
# 4                Cosy guest room near city centre -1
#
#                                              summary  \
# 0           Quiet Garden View Room & Super Fast WiFi
# 1  Cozy studio on your own private floor, 100% in...
# 2                                                NaN
# 3  Stylish and romantic houseboat on fantastic hi...
# 4  2 beds guest room in Amsterdam West near Erasm...
#
#                                          description  host_id  host_name  \
# 0  Quiet Garden View Room & Super Fast WiFi I'm r...     3159     Daniel
# 1  Cozy studio on your own private floor, 100% in...    59484  Alexander
# 2  This nicely furnished, newly renovated apt  is...    56142       Joan
# 3  Stylish and romantic houseboat on fantastic hi...    97647       Flip
# 4  2 beds guest room in Amsterdam West near Erasm...   123414    Michele
#
#    host_since                                         host_about  \
# 0  2008-09-24  Upon arriving in Amsterdam, one can imagine as...
# 1  2009-12-02  Secondary phone nr. + (Phone number hidden by ...
# 2  2009-11-20  We are a retired couple who live in NYC, and h...
# 3  2010-03-23  Marjan works in "eye" the dutch filmmuseum, an...
# 4  2010-05-12  I'm Italian (from Sardinia) , I live in Amster...
#
#   host_response_rate        ...          availability_60  availability_90  \
# 0                NaN        ...                       18               18
# 1               100%        ...                       14               35
# 2               100%        ...                       31               31
# 3                NaN        ...                       35               52
# 4                NaN        ...                       30               39
#
#   availability_365  number_of_reviews  first_review last_review  \
# 0               18                249    2009-03-30  2018-12-30
# 1              184                240    2010-03-02  2019-01-08
# 2              155                  1    2018-01-21  2018-01-21
# 3              164                175    2012-01-09  2018-12-30
# 4              265                438    2010-05-16  2018-12-26
#
#   review_scores_rating  instant_bookable          cancellation_policy  \
# 0                 97.0                 t  strict_14_with_grace_period
# 1                 87.0                 f  strict_14_with_grace_period
# 2                100.0                 f  strict_14_with_grace_period
# 3                 99.0                 t  strict_14_with_grace_period
# 4                 93.0                 f                     moderate
#
#    reviews_per_month
# 0               2.09
# 1               2.22
# 2               0.08
# 3               2.05
# 4               4.15
#
# [5 rows x 36 columns]

# %%
duplicates = pd.read_json('C:\\Users\\Jeffr\\Downloads\\DataSystemProjects\\DataSystemProject\\Analyse_multiple_accounts_multiple_listings\\duplicates.js' ,orient='records')

duplicates_verrijkt = duplicates.merge(df_listings, left_on = 'case_A_id', right_on = 'id', how='left')

agg_df = duplicates_verrijkt.groupby('neighbourhood_cleansed').count()


agg_df = agg_df.iloc[:,1]

type(agg_df)
# Out:
# pandas.core.series.Series

# %%
area_overview = area_overview.set_index('name')
area_overview['duplicates'] = agg_df

# %%
area_overview["risk_rank"] = round(area_overview["listings"] /  area_overview["duplicates"] ,2)
area_overview = area_overview.drop(columns = 'neighbourhood').reset_index
area_overview
# Out:
#                                         accounts  listings  avg_price_night  \
# name
# Bijlmer-Centrum                               94       109        91.073394
# Bijlmer-Oost                                  82       102        99.813725
# Bos en Lommer                               1036      1137       117.425682
# Buitenveldert - Zuidas                       224       237       150.940928
# Centrum-Oost                                1439      1775       188.936901
# Centrum-West                                1850      2317       189.206733
# De Aker - Nieuw Sloten                       112       130       126.423077
# De Baarsjes - Oud-West                      3173      3480       143.556609
# De Pijp - Rivierenbuurt                     2242      2494       157.072173
# Gaasperdam - Driemond                        102       119        95.336134
# Geuzenveld - Slotermeer                      180       206       126.135922
# IJburg - Zeeburgereiland                     403       443       167.417607
# Noord-Oost                                   226       254       118.039370
# Noord-West                                   286       323       118.823529
# Oostelijk Havengebied - Indische Buurt       878       958       125.981211
# Osdorp                                       134       157        97.375796
# Oud-Noord                                    508       572       158.945804
# Oud-Oost                                    1146      1254       143.793461
# Slotervaart                                  349       391       112.109974
# Watergraafsmeer                              513       547       139.497258
# Westerpark                                  1331      1468       140.767711
# Zuid                                        1291      1437       171.004871
#
#                                         percentage_high_availability  \
# name
# Bijlmer-Centrum                                                 26.9
# Bijlmer-Oost                                                    36.6
# Bos en Lommer                                                   18.3
# Buitenveldert - Zuidas                                          31.1
# Centrum-Oost                                                    36.9
# Centrum-West                                                    39.2
# De Aker - Nieuw Sloten                                          41.0
# De Baarsjes - Oud-West                                          20.2
# De Pijp - Rivierenbuurt                                         22.3
# Gaasperdam - Driemond                                           46.3
# Geuzenveld - Slotermeer                                         34.8
# IJburg - Zeeburgereiland                                        30.3
# Noord-Oost                                                      33.2
# Noord-West                                                      30.8
# Oostelijk Havengebied - Indische Buurt                          21.7
# Osdorp                                                          37.3
# Oud-Noord                                                       30.1
# Oud-Oost                                                        18.1
# Slotervaart                                                     21.9
# Watergraafsmeer                                                 23.1
# Westerpark                                                      19.4
# Zuid                                                            28.8
#
#                                         percentage_host_with_multiple_listings  \
# name
# Bijlmer-Centrum                                                           25.0
# Bijlmer-Oost                                                              27.6
# Bos en Lommer                                                             19.8
# Buitenveldert - Zuidas                                                    16.4
# Centrum-Oost                                                              30.3
# Centrum-West                                                              33.1
# De Aker - Nieuw Sloten                                                    26.1
# De Baarsjes - Oud-West                                                    17.4
# De Pijp - Rivierenbuurt                                                   18.4
# Gaasperdam - Driemond                                                     30.1
# Geuzenveld - Slotermeer                                                   26.4
# IJburg - Zeeburgereiland                                                  22.9
# Noord-Oost                                                                21.5
# Noord-West                                                                20.2
# Oostelijk Havengebied - Indische Buurt                                    18.7
# Osdorp                                                                    28.0
# Oud-Noord                                                                 19.1
# Oud-Oost                                                                  18.8
# Slotervaart                                                               26.0
# Watergraafsmeer                                                           14.2
# Westerpark                                                                17.6
# Zuid                                                                      20.1
#
#                                         duplicates  risk_rank
# name
# Bijlmer-Centrum                                  3      36.33
# Bijlmer-Oost                                     6      17.00
# Bos en Lommer                                   30      37.90
# Buitenveldert - Zuidas                           5      47.40
# Centrum-Oost                                    78      22.76
# Centrum-West                                   133      17.42
# De Aker - Nieuw Sloten                           3      43.33
# De Baarsjes - Oud-West                          83      41.93
# De Pijp - Rivierenbuurt                         64      38.97
# Gaasperdam - Driemond                            6      19.83
# Geuzenveld - Slotermeer                          5      41.20
# IJburg - Zeeburgereiland                        15      29.53
# Noord-Oost                                       8      31.75
# Noord-West                                      10      32.30
# Oostelijk Havengebied - Indische Buurt          14      68.43
# Osdorp                                          11      14.27
# Oud-Noord                                       14      40.86
# Oud-Oost                                        22      57.00
# Slotervaart                                     14      27.93
# Watergraafsmeer                                  8      68.38
# Westerpark                                      32      45.88
# Zuid                                            30      47.90

# %%
# area_overview.to_json('area_overview.json' ,orient='records')
